# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

bar = pd.read_csv('./data/weather_barcelona.csv', index_col='Date')
rom = pd.read_csv('./data/weather_rome.csv', index_col='Date')
ams = pd.read_csv('./data/weather_amsterdam.csv', index_col='Date')

temp_max = pd.DataFrame(index = bar.index)

temp_max['Barcelona'] = bar['TempMax']
temp_max['Rome'] = rom['TempMax']
temp_max['Amsterdam'] = ams['TempMax']

# %%
def GradeDay(row):
    if(row['TempMax'] >= row['AvgTempMax']):
        return 'PLUS'
    else:
        return "MINUS"

# %%
rom['GradeDay'] = rom.apply(GradeDay, axis=1)
bar['GradeDay'] = bar.apply(GradeDay, axis=1)
ams['GradeDay'] = ams.apply(GradeDay, axis=1)

# %%
rom.head()
# Out:
#             TempMax  TempMin Rain  AvgTempMax  AvgTempMin GradeDay
# Date
# 2018-01-01       14        8   0           12           4     PLUS
# 2018-01-02       13        7   0           12           4     PLUS
# 2018-01-03       14        1   0           12           4     PLUS
# 2018-01-04       16        6   0           12           4     PLUS
# 2018-01-05       17        7   0           12           3     PLUS

# %%
rom['GradeDay'].value_counts()
# Out:
# PLUS     70
# MINUS    20
# Name: GradeDay, dtype: int64

# %%
cities3 = pd.DataFrame(index=['MINUS','PLUS'])

# %%
cities3['Barcelona'] = bar['GradeDay'].value_counts()
cities3['Rome'] = rom['GradeDay'].value_counts()
cities3['Amsterdam'] = ams['GradeDay'].value_counts()

# %%
cities3
# Out:
#        Barcelona  Rome  Amsterdam
# MINUS         26    20         22
# PLUS          64    70         68

# %%
cities3['Barcelona'].plot(kind='pie', figsize=(7,7))

# %%
cities3.plot(kind='pie', figsize=(15,5), subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001BD904478C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001BD90472E08>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001BD904B12C8>],
#       dtype=object)

# %%
cities3.plot(kind='pie', figsize=(15,5), subplots=True, colors=['b','g'])
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001BD9053A308>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001BD9055EE88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001BD90596BC8>],
#       dtype=object)

# %%
cities3.plot(kind='pie', figsize=(15,5), subplots=True, colors=['b','g'], 
             labels=['colder','warmer'], autopct='%.0f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001BD9061FEC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001BD9064A888>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001BD90683308>],
#       dtype=object)

# %%
cities3.plot(kind='pie', figsize=(10,10), subplots=True, colors=['b','g'], 
             labels=['colder','warmer'], autopct='%.0f%%', fontsize=20,
            textprops=dict(color='w'), layout=(2,2))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001BD9089B188>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BD908C3348>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BD90736B48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BD9076EAC8>]],
#       dtype=object)

# %%
cities3.plot(kind='pie', figsize=(15,5), subplots=True, colors=['b','g'], 
             labels=['colder','warmer'], autopct='%.0f%%', fontsize=20,
            textprops=dict(color='w'), explode=(0.2,0))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001BD90848048>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001BD9087EC88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001BD908F8088>],
#       dtype=object)
