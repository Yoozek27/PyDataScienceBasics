# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
frame = pd.read_csv('./data/mcdonalds.csv',
                    usecols=['Item','Category','Calories','TotalFat',
                            'Sugars','Protein','Cholesterol'])

# %%
frame.head()
# Out:
#     Category                              Item  Calories  TotalFat  \
# 0  Breakfast                      Egg McMuffin       300      13.0
# 1  Breakfast                 Egg White Delight       250       8.0
# 2  Breakfast                  Sausage McMuffin       370      23.0
# 3  Breakfast         Sausage McMuffin with Egg       450      28.0
# 4  Breakfast  Sausage McMuffin with Egg Whites       400      23.0
#
#    Cholesterol  Sugars  Protein
# 0          260       3       17
# 1           25       3       18
# 2           45       2       14
# 3          285       2       21
# 4           50       2       21

# %%
frame.TotalFat.head()
# Out:
# 0    13.0
# 1     8.0
# 2    23.0
# 3    28.0
# 4    23.0
# Name: TotalFat, dtype: float64

# %%
frame['TotalFat'].head()
# Out:
# 0    13.0
# 1     8.0
# 2    23.0
# 3    28.0
# 4    23.0
# Name: TotalFat, dtype: float64

# %%
SugarAndFat = frame.Sugars + frame.TotalFat
frame['SugarAndFat'] = SugarAndFat

# %%
frame.head()
# Out:
#     Category                              Item  Calories  TotalFat  \
# 0  Breakfast                      Egg McMuffin       300      13.0
# 1  Breakfast                 Egg White Delight       250       8.0
# 2  Breakfast                  Sausage McMuffin       370      23.0
# 3  Breakfast         Sausage McMuffin with Egg       450      28.0
# 4  Breakfast  Sausage McMuffin with Egg Whites       400      23.0
#
#    Cholesterol  Sugars  Protein  SugarAndFat
# 0          260       3       17         16.0
# 1           25       3       18         11.0
# 2           45       2       14         25.0
# 3          285       2       21         30.0
# 4           50       2       21         25.0

# %%
SugarAndFat.head()
# Out:
# 0    16.0
# 1    11.0
# 2    25.0
# 3    30.0
# 4    25.0
# dtype: float64

# %%
frame['SugarAndProtein'] = frame.Sugars + frame.Protein
frame.head()
# Out:
#     Category                              Item  Calories  TotalFat  \
# 0  Breakfast                      Egg McMuffin       300      13.0
# 1  Breakfast                 Egg White Delight       250       8.0
# 2  Breakfast                  Sausage McMuffin       370      23.0
# 3  Breakfast         Sausage McMuffin with Egg       450      28.0
# 4  Breakfast  Sausage McMuffin with Egg Whites       400      23.0
#
#    Cholesterol  Sugars  Protein  SugarAndFat  SugarAndProtein
# 0          260       3       17         16.0               20
# 1           25       3       18         11.0               21
# 2           45       2       14         25.0               16
# 3          285       2       21         30.0               23
# 4           50       2       21         25.0               23

# %%
frame.insert(loc=2, column='SPF', value=frame.Protein+frame.TotalFat)
frame.head()
# Out:
#     Category                              Item   SPF  Calories  TotalFat  \
# 0  Breakfast                      Egg McMuffin  30.0       300      13.0
# 1  Breakfast                 Egg White Delight  26.0       250       8.0
# 2  Breakfast                  Sausage McMuffin  37.0       370      23.0
# 3  Breakfast         Sausage McMuffin with Egg  49.0       450      28.0
# 4  Breakfast  Sausage McMuffin with Egg Whites  44.0       400      23.0
#
#    Cholesterol  Sugars  Protein  SugarAndFat  SugarAndProtein
# 0          260       3       17         16.0               20
# 1           25       3       18         11.0               21
# 2           45       2       14         25.0               16
# 3          285       2       21         30.0               23
# 4           50       2       21         25.0               23

# %%
del frame['SugarAndProtein']

# %%
frame.head()
# Out:
#     Category                              Item   SPF  Calories  TotalFat  \
# 0  Breakfast                      Egg McMuffin  30.0       300      13.0
# 1  Breakfast                 Egg White Delight  26.0       250       8.0
# 2  Breakfast                  Sausage McMuffin  37.0       370      23.0
# 3  Breakfast         Sausage McMuffin with Egg  49.0       450      28.0
# 4  Breakfast  Sausage McMuffin with Egg Whites  44.0       400      23.0
#
#    Cholesterol  Sugars  Protein  SugarAndFat
# 0          260       3       17         16.0
# 1           25       3       18         11.0
# 2           45       2       14         25.0
# 3          285       2       21         30.0
# 4           50       2       21         25.0

# %%
frame = frame.drop(columns=['SugarAndFat'])
frame.head()
# Out:
#     Category                              Item   SPF  Calories  TotalFat  \
# 0  Breakfast                      Egg McMuffin  30.0       300      13.0
# 1  Breakfast                 Egg White Delight  26.0       250       8.0
# 2  Breakfast                  Sausage McMuffin  37.0       370      23.0
# 3  Breakfast         Sausage McMuffin with Egg  49.0       450      28.0
# 4  Breakfast  Sausage McMuffin with Egg Whites  44.0       400      23.0
#
#    Cholesterol  Sugars  Protein
# 0          260       3       17
# 1           25       3       18
# 2           45       2       14
# 3          285       2       21
# 4           50       2       21

# %%
frame.drop(labels='SugarAndFat',axis=1,inplace=True) #axis=0 - wiersz, axis=1 - kolumna
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-8ea9e0837483> in <module>
# ----> 1 frame.drop(labels='SugarAndFat',axis=1,inplace=True) #axis=0 - wiersz, axis=1 - kolumna
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
frame.drop(columns=['SPF'], inplace=True)

# %%
frame.head()
# Out:
#     Category                              Item  Calories  TotalFat  \
# 0  Breakfast                      Egg McMuffin       300      13.0
# 1  Breakfast                 Egg White Delight       250       8.0
# 2  Breakfast                  Sausage McMuffin       370      23.0
# 3  Breakfast         Sausage McMuffin with Egg       450      28.0
# 4  Breakfast  Sausage McMuffin with Egg Whites       400      23.0
#
#    Cholesterol  Sugars  Protein
# 0          260       3       17
# 1           25       3       18
# 2           45       2       14
# 3          285       2       21
# 4           50       2       21
