# %%
import pandas as pd
import numpy as np

df_blood = pd.DataFrame({'Group'      :  ['0','0','A','A','B','B','AB','AB'],
                         'Rh'         :  ['+','-','+','-','+','-','+','-'],
                         'Population' :  [31,6,32,6,15,2,7,1]})

# %%
df_blood
# Out:
#   Group Rh  Population
# 0     0  +          31
# 1     0  -           6
# 2     A  +          32
# 3     A  -           6
# 4     B  +          15
# 5     B  -           2
# 6    AB  +           7
# 7    AB  -           1

# %%
df_blood.to_csv('blood.csv')

# %%
df_blood.loc[:,'Population']/=100

# %%
df_blood
# Out:
#   Group Rh  Population
# 0     0  +        0.31
# 1     0  -        0.06
# 2     A  +        0.32
# 3     A  -        0.06
# 4     B  +        0.15
# 5     B  -        0.02
# 6    AB  +        0.07
# 7    AB  -        0.01

# %%
df_blood.to_csv('blood.csv', index=False)

# %%
df_blood.to_csv('blood.csv', index=False, columns=['Group','Rh'])

# %%
pd.read_csv('blood.csv')
# Out:
#   Group Rh
# 0     0  +
# 1     0  -
# 2     A  +
# 3     A  -
# 4     B  +
# 5     B  -
# 6    AB  +
# 7    AB  -

# %%
df_blood.to_csv('blood.csv', index=False, columns=['Group','Rh'], sep=';')

# %%
pd.read_csv('blood.csv', sep=';')
# Out:
#   Group Rh
# 0     0  +
# 1     0  -
# 2     A  +
# 3     A  -
# 4     B  +
# 5     B  -
# 6    AB  +
# 7    AB  -

# %%
df_blood.to_csv('blood.csv', index=False, columns=['Group','Rh'], sep=';', mode='a',
               header=False)

# %%
pd.read_csv('blood.csv', sep=';')
# Out:
#    Group Rh
# 0      0  +
# 1      0  -
# 2      A  +
# 3      A  -
# 4      B  +
# 5      B  -
# 6     AB  +
# 7     AB  -
# 8      0  +
# 9      0  -
# 10     A  +
# 11     A  -
# 12     B  +
# 13     B  -
# 14    AB  +
# 15    AB  -

# %%
df_blood.to_json('blood.json')

# %%
pd.read_json('blood.json')
# Out:
#   Group Rh  Population
# 0     0  +        0.31
# 1     0  -        0.06
# 2     A  +        0.32
# 3     A  -        0.06
# 4     B  +        0.15
# 5     B  -        0.02
# 6    AB  +        0.07
# 7    AB  -        0.01
